# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
noise = np.random.rand(100)
x = np.linspace(0,100,num=100)
y = - 10*(x-50)*(x-80)*(x-35)/(30*60*15) + 50*(x-20)*(x-50)*(x-80)/(15*15*45)\
    - 10*(x-80)*(x-20)*(x-35)/(30*30*15) + 80*(x-20)*(x-50)*(x-35)/(60*30*45)
z = - 15*(x-50)*(x-80)*(x-35)/(30*60*15) + 40*(x-20)*(x-50)*(x-80)/(15*15*45)\
    - 10*(x-80)*(x-20)*(x-35)/(30*30*15) + 75*(x-20)*(x-50)*(x-35)/(60*30*45)
plt.plot(x,y+150*noise - 75,'.', label='data')
plt.plot(x,y,'r', label='true mean')
plt.plot(x,z,'k', label='trained model')
plt.legend()
plt.show()

# %%
noise = np.random.rand(100)
x = np.linspace(0,100,num=100)
y = - 10*(x-50)*(x-80)*(x-35)/(30*60*15) + 50*(x-20)*(x-50)*(x-80)/(15*15*45)\
    - 10*(x-80)*(x-20)*(x-35)/(30*30*15) + 80*(x-20)*(x-50)*(x-35)/(60*30*45)
z = - 15*(x-50)*(x-80)*(x-35)/(30*60*15) + 40*(x-20)*(x-50)*(x-80)/(15*15*45)\
    - 10*(x-80)*(x-20)*(x-35)/(30*30*15) + 75*(x-20)*(x-50)*(x-35)/(60*30*45)
plt.plot(x,y+150*noise - 75,'.', label='data')
plt.plot(x,y,'r', label='sant medelvärde')
plt.plot(x,z,'k', label='tränad modell')
plt.legend()
plt.show()

# %%
xyp = np.random.randn(2,100)
xyn = np.random.randn(2,100)
plt.scatter(xyp[0],xyp[1],c='pink', label='healthy')
plt.scatter(xyn[0]+2,xyn[1]+1.5,c='black', label='sick')
x = np.linspace(-2,5)
y = -3/4*x + 1.5
plt.plot(x,y, label='decision boundary')
plt.legend()
plt.show()

# %%
xyp = np.random.randn(2,100)
xyn = np.random.randn(2,100)
plt.scatter(xyp[0],xyp[1],c='pink', label='frisk')
plt.scatter(xyn[0]+2,xyn[1]+1.5,c='black', label='sjuklig')
x = np.linspace(-2,5)
y = -3/4*x + 1.5
plt.plot(x,y, label='beslutsgräns')
plt.legend()
plt.show()

# %%
noise = np.random.randn(50) - 0.5
y = np.sin(x)
z = y + 0.1*noise
plt.plot(x,y,'*',c='k', label='true labels')
plt.plot(x,z,'.',c='k', label='predictions')
for i in range(50):
  plt.plot([x[i],x[i]], [y[i],z[i]], 'r')

plt.legend()
plt.show()

# %%
noise = np.random.randn(50) - 0.5
y = np.sin(x)
z = y + 0.1*noise
plt.plot(x,y,'*',c='k', label='sanna etiketter')
plt.plot(x,z,'.',c='k', label='prediktioner')
for i in range(50):
  plt.plot([x[i],x[i]], [y[i],z[i]], 'r')

plt.legend()
plt.show()

# %%
fig=plt.figure(1)
ax=fig.add_subplot(1,1,1)
ax.set_title('Binary classification')

circ=plt.Circle((0,0), radius=1, color='r', fill=False, label= 'truth')
ax.add_patch(circ)
circ=plt.Circle((0.5,0.5), radius=1, color='k', fill=False, label= 'predicted')
ax.add_patch(circ)
plt.axis('equal')

data = np.random.randn(2,100)
plt.scatter(data[0],data[1],c='gray', label='examples')

props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)

# place a text box in upper left in axes coords
ax.text(0.0, 0.0, "TP", fontsize=14, bbox=props)
ax.text(0.7, 0.9, "FP", fontsize=14, bbox=props)
ax.text(-0.5, -0.6, "FN", fontsize=14, bbox=props)
ax.text(-2.0, 2.0, "TN", fontsize=14, bbox=props)

plt.legend()

plt.show()

# %%
fig=plt.figure(1)
ax=fig.add_subplot(1,1,1)
ax.set_title('Binär klassificering')

circ=plt.Circle((0,0), radius=1, color='r', fill=False, label= 'sanning')
ax.add_patch(circ)
circ=plt.Circle((0.5,0.5), radius=1, color='k', fill=False, label= 'predikterat')
ax.add_patch(circ)
plt.axis('equal')

data = np.random.randn(2,100)
plt.scatter(data[0],data[1],c='gray', label='exempel')

props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)

# place a text box in upper left in axes coords
ax.text(0.0, 0.0, "TP", fontsize=14, bbox=props)
ax.text(0.7, 0.9, "FP", fontsize=14, bbox=props)
ax.text(-0.5, -0.6, "FN", fontsize=14, bbox=props)
ax.text(-2.0, 2.0, "TN", fontsize=14, bbox=props)

plt.legend()

plt.show()

# %%
fig=plt.figure(1)
ax=fig.add_subplot(1,1,1)
ax.set_title('Linear functions y = w * x + b')

x = np.linspace(-10,10,100)
plt.plot(x,2*x + 10, label='w=2, b=10', c='b')
plt.plot(x,0.1*x , label='w=0.1, b=0', c='r')
plt.plot(x,-3*x + 5, label='w=-3, b=5', c='g')
plt.plot(x,10*x - 10, label='w=10, b=-10', c='k')

plt.legend()
plt.show()

# %%
fig=plt.figure(1)
ax=fig.add_subplot(1,1,1)
ax.set_title('Linjära funktioner y = w * x + b')

x = np.linspace(-10,10,100)
plt.plot(x,2*x + 10, label='w=2, b=10', c='b')
plt.plot(x,0.1*x , label='w=0.1, b=0', c='r')
plt.plot(x,-3*x + 5, label='w=-3, b=5', c='g')
plt.plot(x,10*x - 10, label='w=10, b=-10', c='k')

plt.legend()
plt.show()

# %%
fig=plt.figure(1)
ax=fig.add_subplot(1,1,1)
ax.set_title('3rd degree polynomials y = ax^3 + bx^2 + cx + d')

x = np.linspace(-5,5,100)
x2 = x*x
x3 = x2*x
plt.plot(x,10*x2, label='10*x^2', c='b')
plt.plot(x,x3 , label='x^3', c='r')
plt.plot(x,x3-10*x2+100, label='x^3 - 10x^2 + 100', c='g')
plt.plot(x,10*x - 10, label='10x - 10', c='k')


plt.legend()
plt.show()

# %%
fig=plt.figure(1)
ax=fig.add_subplot(1,1,1)
ax.set_title('Tredjegradspolynom y = ax^3 + bx^2 + cx + d')

x = np.linspace(-5,5,100)
x2 = x*x
x3 = x2*x
plt.plot(x,10*x2, label='10*x^2', c='b')
plt.plot(x,x3 , label='x^3', c='r')
plt.plot(x,x3-10*x2+100, label='x^3 - 10x^2 + 100', c='g')
plt.plot(x,10*x - 10, label='10x - 10', c='k')


plt.legend()
plt.show()

# %%
fig = plt.figure(1)
ax=fig.add_subplot(1,1,1)
ax.set_title('decision stumps in two variables')

def vertical(x,color):
    plt.plot([x,x], [0,1], c=color, label='x>'+str(x))
    plt.arrow(x,0.5,0.02,0, head_width=0.03, head_length=0.015, color=color)

def horizontal(y,color):
    plt.plot([0,1], [y,y], c=color, label='y>'+str(y))
    plt.arrow(0.5,y,0,0.02, head_width=0.015, head_length=0.04, color=color)

    
vertical(0.1,'k')
vertical(0.4, 'b')
horizontal(0.2, 'r')
horizontal(0.7, 'g')
plt.legend()
plt.xlim(-0.1,1.1)
plt.ylim(-0.1,1.1)
plt.show()

# %%
fig = plt.figure(1)
ax=fig.add_subplot(1,1,1)
ax.set_title('Beslutsstubbar i två variabler')

def vertical(x,color):
    plt.plot([x,x], [0,1], c=color, label='x>'+str(x))
    plt.arrow(x,0.5,0.02,0, head_width=0.03, head_length=0.015, color=color)

def horizontal(y,color):
    plt.plot([0,1], [y,y], c=color, label='y>'+str(y))
    plt.arrow(0.5,y,0,0.02, head_width=0.015, head_length=0.04, color=color)

    
vertical(0.1,'k')
vertical(0.4, 'b')
horizontal(0.2, 'r')
horizontal(0.7, 'g')
plt.legend()
plt.xlim(-0.1,1.1)
plt.ylim(-0.1,1.1)
plt.show()

# %%
fig = plt.figure(1)
ax=fig.add_subplot(1,1,1)
ax.set_title('decision trees in two variables, single tree shown')

def box(ax,x,y):
    pat = plt.Rectangle([x,y],0.1,0.1)
    ax.add_patch(pat)

for i in range(10):
    for j in range(10):
        if np.random.randn()<0.5:
            box(ax,i/10,j/10)

ax.set_aspect('equal')
plt.show()

# %%
fig = plt.figure(1)
ax=fig.add_subplot(1,1,1)
ax.set_title('Beslutsträd i två variabler, ett träd visas')

def box(ax,x,y):
    pat = plt.Rectangle([x,y],0.1,0.1)
    ax.add_patch(pat)

for i in range(10):
    for j in range(10):
        if np.random.randn()<0.5:
            box(ax,i/10,j/10)

ax.set_aspect('equal')
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

fig = plt.figure()
ax = Axes3D(fig)

rad = np.linspace(0, 5, 100)
azm = np.linspace(0, 2 * np.pi, 100)
r, th = np.meshgrid(rad, azm)
z = (r ** 2.0) / 4.0

ax.grid(False)
ax.set_xticks([])
ax.set_yticks([])
plt.subplot(projection="polar")

#plt.pcolormesh(th, r, z)

#plt.plot(azm, r, color='k', ls='none') 
#plt.grid()

plt.show()

# %%
x = np.linspace(0,100,100)
noise1 = np.random.randn(100)
noise2 = np.random.randn(100)

y = np.exp(-x/50) 
z = (x-60)**2/2000 + 0.4
plt.plot(x,y+noise1/20, label='train error')
plt.plot(x,z+noise2/20, label='test error')
plt.ylabel('error')
plt.xlabel('model complexity')
plt.legend()
plt.show()

# %%
x = np.linspace(0,100,100)
noise1 = np.random.randn(100)
noise2 = np.random.randn(100)

y = np.exp(-x/50) 
z = (x-60)**2/2000 + 0.4
plt.plot(x,y+noise1/20, label='träningsfel')
plt.plot(x,z+noise2/20, label='testfel')
plt.ylabel('fel')
plt.xlabel('modellkomplexitet')
plt.legend()
plt.show()

# %%
x = np.linspace(0,20,100)
noise1 = np.random.randn(100)
noise2 = np.random.randn(100)

y = np.exp(-x/50) 
z = (x-60)**2/2000 + 0.4
plt.plot(x,y+noise1/20, label='train error')
plt.plot(x,z+noise2/20, label='test error')
plt.ylabel('error')
plt.xlabel('data size')
plt.legend()
plt.show()

# %%
x = np.linspace(0,20,100)
noise1 = np.random.randn(100)
noise2 = np.random.randn(100)

y = np.exp(-x/50) 
z = (x-60)**2/2000 + 0.4
plt.plot(x,y+noise1/20, label='träningsfel')
plt.plot(x,z+noise2/20, label='testfel')
plt.ylabel('fel')
plt.xlabel('datamängd')
plt.legend()
plt.show()

# %%
x = np.linspace(0,100,100)
noise1 = np.random.randn(100)
noise2 = np.random.randn(100)

y = np.exp(-x/10) + 0.21
plt.plot(x,y+noise1/100, label='träningsfel')
plt.plot(x,y+noise2/100, label='testfel')
plt.ylabel('fel')
plt.xlabel('datamängd')
plt.legend()
plt.show()

# %%
x = np.linspace(0,100,100)
noise1 = np.random.randn(100)
noise2 = np.random.randn(100)

y = np.exp(-x/10) + 0.21
plt.plot(x,y+noise1/100, label='training error')
plt.plot(x,y+noise2/100, label='test error')
plt.ylabel('error')
plt.xlabel('data size')
plt.legend()
plt.show()
